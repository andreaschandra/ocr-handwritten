# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import imutils
from imutils import contours

DIR_PATH = '../data/data-ocr/data-ocr'

filenames = os.listdir(DIR_PATH)

for filename in filenames:
    filepath = os.path.join(DIR_PATH, filename)
    im_arr = cv2.imread(filepath)
    break

# %%
# im_arr = cv2.rotate(im_arr, cv2.ROTATE_90_COUNTERCLOCKWISE)

# %%
plt.imshow(im_arr)

# %%
im_arr = cv2.cvtColor(im_arr, cv2.COLOR_BGR2GRAY)

# %%
# 2x2 Static kernal
kernal = np.ones((2,2), np.uint8)

# %%
_, mask = cv2.threshold(im_arr, 160, 255, cv2.THRESH_BINARY_INV)

# %%
dst = cv2.dilate(mask, kernal,iterations = 1)
dst = cv2.bitwise_not(dst)

# %%
plt.imshow(dst, cmap='gray')

# %%
cv2.imwrite(PATH_TO_DEST+"/Dilation_"+image_name,dst)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7164\1300730725.py in <module>
# ----> 1 cv2.imwrite(PATH_TO_DEST+"/Dilation_"+image_name,dst)
#
# NameError: name 'PATH_TO_DEST' is not defined
